# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect(
    "DRIVER={SQL Server};"
    "SERVER=PE0PLE\SQLEXPRESS;"
    "DATABASE=PortofolioProject;"
    "Trusted_Connection=yes;"
)

query = "SELECT * FROM Superstore"

df = pd.read_sql(query, conn)

df.head()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\S'
# <>:6: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\user\AppData\Local\Temp\ipykernel_4236\3602487082.py:6: SyntaxWarning: invalid escape sequence '\S'
#   "SERVER=PE0PLE\SQLEXPRESS;"
# C:\Users\user\AppData\Local\Temp\ipykernel_4236\3602487082.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  2815.0  CA-2015-135685  11/16/2015  11/18/2015    Second Class    MP-18175
# 1  2816.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
# 2  2817.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
# 3  2818.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
# 4  2819.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
#
#     Customer Name      Segment        Country       City  ... Postal Code  \
# 0  Mike Pelletier  Home Office  United States  Milwaukee  ...     53209.0
# 1   Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
# 2   Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
# 3   Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
# 4   Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  FUR-TA-10000688        Furniture       Tables
# 1     East  OFF-BI-10001510  Office Supplies      Binders
# 2     East  FUR-CH-10003817        Furniture       Chairs
# 3     East  FUR-FU-10000308        Furniture  Furnishings
# 4     East  OFF-ST-10003208  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0  Chromcraft Bull-Nose Wood Round Conference Tab...   65355.0       3.0
# 1          Deluxe Heavy-Duty Vinyl Round Ring Binder    1146.0       5.0
# 2                     Global Value Steno Chair, Gray    6074.0       1.0
# 3           Deflect-o Glass Clear Studded Chair Mats   12436.0       2.0
# 4                 Adjustable Depth Letter/Legal Cart  108876.0       6.0
#
#    Discount     Profit
# 0       0.0  1111035.0
# 1       0.0     5157.0
# 2       0.0    15185.0
# 3       0.0   273592.0
# 4       0.0  3157404.0
#
# [5 rows x 21 columns]

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  2815.0  CA-2015-135685  11/16/2015  11/18/2015    Second Class    MP-18175
# 1  2816.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
# 2  2817.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
# 3  2818.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
# 4  2819.0  CA-2015-104626    9/1/2015    9/8/2015  Standard Class    DR-12940
# 5  2820.0  CA-2016-160500    5/5/2016    5/8/2016     First Class    DM-13015
# 6  2821.0  CA-2016-160500    5/5/2016    5/8/2016     First Class    DM-13015
# 7  2822.0  CA-2017-100202  12/31/2016    1/5/2017  Standard Class    BD-11620
# 8  2823.0  CA-2017-131016   9/18/2017   9/20/2017     First Class    DC-12850
# 9  2824.0  CA-2017-131016   9/18/2017   9/20/2017     First Class    DC-12850
#
#      Customer Name      Segment        Country       City  ... Postal Code  \
# 0   Mike Pelletier  Home Office  United States  Milwaukee  ...     53209.0
# 1    Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
# 2    Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
# 3    Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
# 4    Daniel Raglin  Home Office  United States   Franklin  ...      2038.0
# 5    Darrin Martin     Consumer  United States  Encinitas  ...     92024.0
# 6    Darrin Martin     Consumer  United States  Encinitas  ...     92024.0
# 7  Brian DeCherney     Consumer  United States    Anaheim  ...     92804.0
# 8     Dan Campbell     Consumer  United States  Arlington  ...     76017.0
# 9     Dan Campbell     Consumer  United States  Arlington  ...     76017.0
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  FUR-TA-10000688        Furniture       Tables
# 1     East  OFF-BI-10001510  Office Supplies      Binders
# 2     East  FUR-CH-10003817        Furniture       Chairs
# 3     East  FUR-FU-10000308        Furniture  Furnishings
# 4     East  OFF-ST-10003208  Office Supplies      Storage
# 5     West  OFF-BI-10003784  Office Supplies      Binders
# 6     West  FUR-TA-10003748        Furniture       Tables
# 7     West  TEC-PH-10002563       Technology       Phones
# 8  Central  OFF-AR-10000122  Office Supplies          Art
# 9  Central  OFF-ST-10000352  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0  Chromcraft Bull-Nose Wood Round Conference Tab...   65355.0       3.0
# 1          Deluxe Heavy-Duty Vinyl Round Ring Binder    1146.0       5.0
# 2                     Global Value Steno Chair, Gray    6074.0       1.0
# 3           Deflect-o Glass Clear Studded Chair Mats   12436.0       2.0
# 4                 Adjustable Depth Letter/Legal Cart  108876.0       6.0
# 5                       Computer Printout Index Tabs     672.0       5.0
# 6                    Bevis 36 x 72 Conference Tables  298776.0       3.0
# 7                                   Adtran 1202752G1  302376.0       3.0
# 8                                         Newell 314    8928.0       2.0
# 9           Acco Perma 2700 Stacking Storage Drawers   47584.0       2.0
#
#    Discount     Profit
# 0       0.0  1111035.0
# 1       0.0     5157.0
# 2       0.0    15185.0
# 3       0.0   273592.0
# 4       0.0  3157404.0
# 5       2.0     2352.0
# 6       2.0    74694.0
# 7       2.0   226782.0
# 8       2.0      558.0
# 9       2.0    -2974.0
#
# [10 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   float64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   float64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(6), object(15)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000  9.994000e+03  9994.000000  9994.000000
# mean   4997.500000  55190.379428  1.132271e+05     3.789574     1.754653
# std    2885.163629  32063.693350  5.186212e+05     2.225110     3.119014
# min       1.000000   1040.000000  3.000000e+00     1.000000     0.000000
# 25%    2499.250000  23223.000000  2.516000e+03     2.000000     0.000000
# 50%    4997.500000  56430.500000  1.108800e+04     3.000000     2.000000
# 75%    7495.750000  90008.000000  5.399175e+04     5.000000     2.000000
# max    9994.000000  99301.000000  2.396266e+07    14.000000    45.000000
#
#              Profit
# count  9.994000e+03
# mean   1.800957e+05
# std    1.722971e+06
# min   -3.839990e+07
# 25%    2.245000e+03
# 50%    3.630900e+04
# 75%    1.509840e+05
# max    6.719981e+07

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000  9.994000e+03  9994.000000  9994.000000
# mean   4997.500000  55190.379428  1.132271e+05     3.789574     1.754653
# std    2885.163629  32063.693350  5.186212e+05     2.225110     3.119014
# min       1.000000   1040.000000  3.000000e+00     1.000000     0.000000
# 25%    2499.250000  23223.000000  2.516000e+03     2.000000     0.000000
# 50%    4997.500000  56430.500000  1.108800e+04     3.000000     2.000000
# 75%    7495.750000  90008.000000  5.399175e+04     5.000000     2.000000
# max    9994.000000  99301.000000  2.396266e+07    14.000000    45.000000
#
#              Profit
# count  9.994000e+03
# mean   1.800957e+05
# std    1.722971e+06
# min   -3.839990e+07
# 25%    2.245000e+03
# 50%    3.630900e+04
# 75%    1.509840e+05
# max    6.719981e+07

# %% [markdown]
# # MISSING VALUE

# %%
df.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # ANALISIS DASAR

# %%
df['Sales'].sum()
# Out:
# np.float64(1131591720.0)

# %%
df['Profit'].sum()
# Out:
# np.float64(1799876538.0)

# %%
df['Order ID'].nunique()
# Out:
# 5009

# %% [markdown]
# # VISUALISASI

# %%
# Sales by Category

import matplotlib.pyplot as plt

sales_cat = df.groupby('Category')['Sales'].sum()

sales_cat.plot(kind='bar')

plt.title('Sales by Category')
plt.ylabel('Sales')
plt.show()
